# %% [markdown]
# # Import Pandas

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# # Pandas Data Structure

# %%
s = pd.Series([10,20,30])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({
    "name":["anitha","suji"],
    "age":[20,20]})
df
# Out:
#      name  age
# 0  anitha   20
# 1    suji   20

# %% [markdown]
# # Writing the data into files

# %%
df.to_csv('data.csv',index=False)

# %% [markdown]
# # Reading data(CSV)

# %%
df=pd.read_csv(r"C:\Users\ASUS\data.csv")
df
# Out:
#         city  Temp  Humidity condition
# 0   Kakinada    87        65     sunny
# 1      Vizag    97        65     rainy
# 2        Hyd    65        67    cloudy
# 3  vijaywada    45        45     sunny
# 4    chennai    74        67     sunny
# 5   Benglore    34        64    cloudy
# 6     Mumbai    23        43    cloudy

# %% [markdown]
# # Exploring Data

# %%
df.head()
# Out:
#         city  Temp  Humidity condition
# 0   Kakinada    87        65     sunny
# 1      Vizag    97        65     rainy
# 2        Hyd    65        67    cloudy
# 3  vijaywada    45        45     sunny
# 4    chennai    74        67     sunny

# %%
df.tail()
# Out:
#         city  Temp  Humidity condition
# 2        Hyd    65        67    cloudy
# 3  vijaywada    45        45     sunny
# 4    chennai    74        67     sunny
# 5   Benglore    34        64    cloudy
# 6     Mumbai    23        43    cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       7 non-null      object
#  1   Temp       7 non-null      int64
#  2   Humidity   7 non-null      int64
#  3   condition  7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 356.0+ bytes

# %%
df['city'][df['condition']=='Rainy']
# Out:
# Series([], Name: city, dtype: object)

# %%
df.shape
# Out:
# (7, 4)

# %%
df[2:5]
# Out:
#         city  Temp  Humidity condition
# 2        Hyd    65        67    cloudy
# 3  vijaywada    45        45     sunny
# 4    chennai    74        67     sunny

# %% [markdown]
# # slicing

# %%
df.columns
# Out:
# Index(['city', 'Temp', 'Humidity', 'condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df.dtypes
# Out:
# city         object
# Temp          int64
# Humidity      int64
# condition    object
# dtype: object

# %%
df.city
# Out:
# 0     Kakinada
# 1        Vizag
# 2          Hyd
# 3    vijaywada
# 4      chennai
# 5     Benglore
# 6       Mumbai
# Name: city, dtype: object

# %%
df['city']
# Out:
# 0     Kakinada
# 1        Vizag
# 2          Hyd
# 3    vijaywada
# 4      chennai
# 5     Benglore
# 6       Mumbai
# Name: city, dtype: object

# %%
df[['city','Humidity']]
# Out:
#         city  Humidity
# 0   Kakinada        65
# 1      Vizag        65
# 2        Hyd        67
# 3  vijaywada        45
# 4    chennai        67
# 5   Benglore        64
# 6     Mumbai        43

# %% [markdown]
# #  Missing value

# %%
df.isnull()
# Out:
#     city   Temp  Humidity  condition
# 0  False  False     False      False
# 1  False  False     False      False
# 2  False  False     False      False
# 3  False  False     False      False
# 4  False  False     False      False
# 5  False  False     False      False
# 6  False  False     False      False

# %%
df = pd.DataFrame({
    "name":["lavs","hanna","anu"],
    "age":[25,23,None]
})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame({
#       2     "name":["lavs","hanna","anu"],
#       3     "age":[25,23,None]
#       4 })
#       5 df
#
# NameError: name 'pd' is not defined

# %%
df.isnull()
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False   True

# %%
df.isnull().sum()
# Out:
# name    0
# age     1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#   name  age
# 2  anu  NaN

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df
# Out:
#    name   age
# 0  lavs  25.0
# 1  mini  23.0
# 2   anu  24.0

# %%
df_clean = df.dropna()

# %%
df_clean
# Out:
#    name   age
# 0  lavs  25.0
# 1  mini  23.0
# 2   anu  24.0

# %% [markdown]
# # Duplicates

# %%
df = pd.DataFrame({
    "name":["mini","anu","mini"],
    "age":[23,25,23]
})
df
# Out:
#    name  age
# 0  mini   23
# 1   anu   25
# 2  mini   23

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    name  age
# 2  mini   23

# %%
df = df.drop_duplicates()
df
# Out:
#    name  age
# 0  mini   23
# 1   anu   25
